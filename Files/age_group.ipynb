# %%
import pandas as pd

# %%
df = pd.read_csv('y_test.csv')
# df2 = pd.read_csv('y_test.csv')

# %%
bins = [4, 6, 10, 14]
labels = ['4-6', '7-10', '11-14']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True, include_lowest=True)
# df2['Age Group'] = pd.cut(df2['Age'], bins=bins, labels=labels, right=True, include_lowest=True)

# %%
df.to_csv("y_test_age_group.csv", index=False)
# df2.to_csv("y_test_age_group.csv", index=False)
df
# Out:
#                                    Name Gender  Age  Gender_bin Age Group
# 0    test_pfstar/003m13bh_list_ph13.wav      m   13           1     11-14
# 1      test_pfstar/004m04bh_digits4.wav      m    4           1       4-6
# 2      test_pfstar/004m04bh_digits9.wav      m    4           1       4-6
# 3      test_pfstar/004m08bh_digits9.wav      m    8           1      7-10
# 4    test_pfstar/004m08bh_list_ph04.wav      m    8           1      7-10
# ..                                  ...    ...  ...         ...       ...
# 124   test_pfstar/210f08sp_digits10.wav      f    8           0      7-10
# 125     test_pfstar/210f08sp_list_5.wav      f    8           0      7-10
# 126  test_pfstar/210f08sp_list_ph20.wav      f    8           0      7-10
# 127   test_pfstar/210f08sp_w_list5a.wav      f    8           0      7-10
# 128   test_pfstar/210f08sp_w_list5b.wav      f    8           0      7-10
#
# [129 rows x 5 columns]
