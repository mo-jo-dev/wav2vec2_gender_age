# %%
import pandas as pd

# %%
df = pd.read_csv('y_train.csv')
# df2 = pd.read_csv('y_test.csv')

# %%
bins = [4, 6, 9, 14]
labels = ['4-6', '7-9', '10-14']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True, include_lowest=True)
# df2['Age Group'] = pd.cut(df2['Age'], bins=bins, labels=labels, right=True, include_lowest=True)

# %%
df.to_csv("y_train_age_group.csv", index=False)
# df2.to_csv("y_test_age_group.csv", index=False)
df
# Out:
#                                          Name Gender  Age  Gender_bin  \
# 0           train_pfstar/001f12bh_digits1.wav      f   12           0
# 1           train_pfstar/001f12bh_digits6.wav      f   12           0
# 2            train_pfstar/001f12bh_list_1.wav      f   12           0
# 3         train_pfstar/001f12bh_list_ph01.wav      f   12           0
# 4         train_pfstar/001f12bh_list_ph06.wav      f   12           0
# ..                                        ...    ...  ...         ...
# 851       train_pfstar/248f08sp_list_ph13.wav      f    8           0
# 852       train_pfstar/248f08sp_list_ph18.wav      f    8           0
# 853  train_pfstar/248f08sp_sentences3or8a.wav      f    8           0
# 854        train_pfstar/248f08sp_w_list3a.wav      f    8           0
# 855        train_pfstar/248f08sp_w_list3b.wav      f    8           0
#
#     Age Group
# 0       10-14
# 1       10-14
# 2       10-14
# 3       10-14
# 4       10-14
# ..        ...
# 851       7-9
# 852       7-9
# 853       7-9
# 854       7-9
# 855       7-9
#
# [856 rows x 5 columns]
