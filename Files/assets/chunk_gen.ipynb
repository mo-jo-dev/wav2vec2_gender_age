# %%
import webrtcvad
import wave
import contextlib

def read_wave(path):
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        sample_width = wf.getsampwidth()
        sample_rate = wf.getframerate()
        frames = wf.readframes(wf.getnframes())
        return frames, sample_rate
    

def write_wave(path, audio, sample_rate):
    with wave.open(path, 'wb') as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(sample_rate)
        wf.writeframes(audio)

def find_best_chunk(audio_path, chunk_duration_ms=30000, aggressiveness=3):
    vad = webrtcvad.Vad(aggressiveness)
    frames, sample_rate = read_wave(audio_path)

    frame_duration = 30
    frame_size = int(sample_rate * frame_duration / 1000) * 2


    speech_frames = []
    current_speech = b""
    max_speech = b""

    for i in range(0, len(frames), frame_size):
        frame = frames[i:i + frame_size]
        if len(frame) < frame_size:
            break
        if vad.is_speech(frame, sample_rate):
            current_speech += frame
        else:
            if len(current_speech) > len(max_speech):
                max_speech = current_speech
            current_speech = b""


    if len(current_speech) > len(max_speech):
        max_speech = current_speech


    max_duration_bytes = (sample_rate * chunk_duration_ms // 1000) * 2
    best_chunk = max_speech[:max_duration_bytes]


    output_path = audio_path.replace(".wav", "_best_chunk.wav")
    write_wave(output_path, best_chunk, sample_rate)
    print(f"Best chunk saved to {output_path}")

audio_path = " "
find_best_chunk(audio_path, chunk_duration_ms=30000)

# %%
import webrtcvad
import wave
import contextlib
import os

def read_wave(path):
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        sample_width = wf.getsampwidth()
        sample_rate = wf.getframerate()
        frames = wf.readframes(wf.getnframes())
        return frames, sample_rate

def write_wave(path, audio, sample_rate):
    with wave.open(path, 'wb') as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(sample_rate)
        wf.writeframes(audio)

def find_best_chunk(audio_path, chunk_duration_ms=30000, aggressiveness=3):
    vad = webrtcvad.Vad(aggressiveness)
    frames, sample_rate = read_wave(audio_path)

    frame_duration = 30
    frame_size = int(sample_rate * frame_duration / 1000) * 2

    speech_frames = []
    current_speech = b""
    max_speech = b""

    for i in range(0, len(frames), frame_size):
        frame = frames[i:i + frame_size]
        if len(frame) < frame_size:
            break
        if vad.is_speech(frame, sample_rate):
            current_speech += frame
        else:
            if len(current_speech) > len(max_speech):
                max_speech = current_speech
            current_speech = b""

    if len(current_speech) > len(max_speech):
        max_speech = current_speech

    max_duration_bytes = (sample_rate * chunk_duration_ms // 1000) * 2
    best_chunk = max_speech[:max_duration_bytes]

    output_path = audio_path.replace(".wav", "_best_chunk.wav")
    write_wave(output_path, best_chunk, sample_rate)
    print(f"Best chunk saved to {output_path}")

def process_folder(folder_path, chunk_duration_ms=30000, aggressiveness=3):
    for filename in os.listdir(folder_path):
        if filename.endswith(".wav"):
            audio_path = os.path.join(folder_path, filename)
            find_best_chunk(audio_path, chunk_duration_ms, aggressiveness)

# Folder path containing the audio files
folder_path = "train_pfstar"
process_folder(folder_path, chunk_duration_ms=30000)
# Out:
# Best chunk saved to train_pfstar/001m14bh_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/004m10bh_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_list_ph25_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_list_ph35_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_list_ph37_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_list_ph30_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_list_ph33_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_list_ph30_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/194f08sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_list_ph32_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_list_ph20_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_list_ph39_best_chunk.wav
# Best chunk saved to train_pfstar/004m08bh_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_list_ph19_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_list_ph35_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_list_ph18_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_list_ph33_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_list_ph20_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_list_ph22_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_list_ph23_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_w_list4a_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_list_ph32_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/005m08bh_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_w_list5b_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_list_ph26_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_list_ph28_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_list_ph31_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_w_list4a_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/005m08bh_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_list_ph24_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_list_ph37_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_list_ph24_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/005m10bh_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/006m10nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/006m10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_list_ph37_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/163f10sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_list_ph32_best_chunk.wav
# Best chunk saved to train_pfstar/210f08sp_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_list_ph26_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_w_list5b_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/004m10bh_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_list_ph29_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_list_ph23_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/194f08sp_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_list_ph33_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/005m10bh_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_w_list5b_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_list_ph25_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/194f08sp_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/163f10sp_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/006m10nl_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_list_ph22_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/163f10sp_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_list_ph22_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_w_list5b_best_chunk.wav
# Best chunk saved to train_pfstar/005m10bh_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/005m08bh_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/199m08sp_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_list_ph26_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_list_ph27_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_list_ph34_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_w_list4b_best_chunk.wav
# Best chunk saved to train_pfstar/043m06bh_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/004m10bh_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/004f05bh_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_list_ph31_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_list_ph25_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/006m10nl_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_list_ph22_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/005m10bh_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_list_ph25_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/045f07nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_list_ph30_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_w_list4a_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_list_ph27_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_list_ph19_best_chunk.wav
# Best chunk saved to train_pfstar/041f07nl_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/035m10nl_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/005f06bh_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/123f07nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/031f10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/040f09nl_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_list_ph23_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_list_ph05_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_list_ph30_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_list_ph29_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_list_ph33_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_list_ph25_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_list_ph18_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/005m08bh_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_list_ph32_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_list_ph35_best_chunk.wav
# Best chunk saved to train_pfstar/035m10nl_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_list_ph35_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/010m11nl_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/006m10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/036f10nl_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_w_list4a_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_list_ph19_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/004m10bh_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_list_ph37_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_w_list4a_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_list_ph31_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/004f05bh_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_list_ph20_best_chunk.wav
# Best chunk saved to train_pfstar/028m10nl_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_list_ph14_best_chunk.wav
# Best chunk saved to train_pfstar/196f08sp_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/011f10nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_list_ph31_best_chunk.wav
# Best chunk saved to train_pfstar/005m10bh_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/162f09sp_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/201m08sp_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_w_list2b_best_chunk.wav
# ...
# Best chunk saved to train_pfstar/035m10nl_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/203f08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/197m08sp_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/001f12bh_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/043f09nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/193f08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/169f10sp_sentences4or9b_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/165m10sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_list_ph36_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/004m08bh_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_list_ph04_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/007m10nl_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_list_ph24_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/032m11nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/211m08sp_list_ph21_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/187f08sp_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/191f07sp_w_list1b_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/035m10nl_list_ph35_best_chunk.wav
# Best chunk saved to train_pfstar/195m08sp_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/163f10sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_list_ph34_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_list_ph03_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_list_ph16_best_chunk.wav
# Best chunk saved to train_pfstar/002m10nl_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/004f11nl_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/082f06nl_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_list_ph02_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_w_list2_best_chunk.wav
# Best chunk saved to train_pfstar/199m08sp_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/006f10bh_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/043m07nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/003m13bh_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/016f10nl_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/042f08nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/186m10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_list_ph18_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/182f09sp_list_ph32_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_w_list1a_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/178m09sp_list_ph23_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/083f07nl_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/003m10bh_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_w_list5a_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/039f11nl_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_w_list3b_best_chunk.wav
# Best chunk saved to train_pfstar/168f09sp_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/202f07sp_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_list_ph20_best_chunk.wav
# Best chunk saved to train_pfstar/183f10sp_list_ph28_best_chunk.wav
# Best chunk saved to train_pfstar/012f11nl_adapt_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/167m10sp_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_list_ph07_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_sentences4or9a_best_chunk.wav
# Best chunk saved to train_pfstar/042f07nl_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/044m06nl_w_list4b_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/164m10sp_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/041f09nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/176m10sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_w_list4b_best_chunk.wav
# Best chunk saved to train_pfstar/179m09sp_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_list_ph29_best_chunk.wav
# Best chunk saved to train_pfstar/001m14bh_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/194f08sp_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/041m06nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/185f10sp_w_list5_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_list_ph26_best_chunk.wav
# Best chunk saved to train_pfstar/082f07nl_list_ph12_best_chunk.wav
# Best chunk saved to train_pfstar/038m11nl_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/181f10sp_list_ph31_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/020m12bh_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_list_ph06_best_chunk.wav
# Best chunk saved to train_pfstar/170m10sp_sentences5or10a_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/030m10nl_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/002f12bh_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/035m10nl_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/189f08sp_list_ph34_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_w_list3_best_chunk.wav
# Best chunk saved to train_pfstar/042m10nl_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_w_list4_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/208f08sp_list_ph18_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_w_list1_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_sentences4or9_best_chunk.wav
# Best chunk saved to train_pfstar/002m14bh_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_list_ph01_best_chunk.wav
# Best chunk saved to train_pfstar/042m06nl_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/054m06nl_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/166f09sp_adapt_list_1_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/083m07nl_digits8_best_chunk.wav
# Best chunk saved to train_pfstar/174m09sp_adapt_digits4_best_chunk.wav
# Best chunk saved to train_pfstar/180f09sp_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/248f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/190f08sp_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/081m06nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_list_ph010_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/192f08sp_w_list2a_best_chunk.wav
# Best chunk saved to train_pfstar/188f08sp_list_ph28_best_chunk.wav
# Best chunk saved to train_pfstar/210f08sp_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/213m08sp_w_list3a_best_chunk.wav
# Best chunk saved to train_pfstar/022m11bh_digits7_best_chunk.wav
# Best chunk saved to train_pfstar/008m11nl_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_list_ph40_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/216m10sp_list_ph26_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/173m10sp_list_ph13_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_list_ph38_best_chunk.wav
# Best chunk saved to train_pfstar/084m07nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/040f07nl_adapt_list_5_best_chunk.wav
# Best chunk saved to train_pfstar/042f06nl_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/212m08sp_w_list2b_best_chunk.wav
# Best chunk saved to train_pfstar/161m10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_list_ph27_best_chunk.wav
# Best chunk saved to train_pfstar/045m06nl_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/004m08bh_adapt_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/007f13bh_list_2_best_chunk.wav
# Best chunk saved to train_pfstar/045m08nl_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/041f08nl_list_ph11_best_chunk.wav
# Best chunk saved to train_pfstar/034m11nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/177f09sp_adapt_digits2_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_sentences2or7a_best_chunk.wav
# Best chunk saved to train_pfstar/206f08sp_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/026f10nl_adapt_digits1_best_chunk.wav
# Best chunk saved to train_pfstar/171m10sp_sentences1or6b_best_chunk.wav
# Best chunk saved to train_pfstar/001m10nl_sentences1or6a_best_chunk.wav
# Best chunk saved to train_pfstar/172f10sp_sentences2or7b_best_chunk.wav
# Best chunk saved to train_pfstar/200f08sp_sentences5or10_best_chunk.wav
# Best chunk saved to train_pfstar/198f08sp_sentences3or8a_best_chunk.wav
# Best chunk saved to train_pfstar/204m08sp_list_4_best_chunk.wav
# Best chunk saved to train_pfstar/045f07nl_adapt_digits10_best_chunk.wav
# Best chunk saved to train_pfstar/210f08sp_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/033m10nl_sentences3or8b_best_chunk.wav
# Best chunk saved to train_pfstar/205m08sp_list_ph15_best_chunk.wav
# Best chunk saved to train_pfstar/005m14bh_digits5_best_chunk.wav
# Best chunk saved to train_pfstar/020m10nl_sentences5or10b_best_chunk.wav
# Best chunk saved to train_pfstar/004m08bh_list_ph09_best_chunk.wav
# Best chunk saved to train_pfstar/163f10sp_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_adapt_list_3_best_chunk.wav
# Best chunk saved to train_pfstar/043f07nl_adapt_digits3_best_chunk.wav
# Best chunk saved to train_pfstar/003m10nl_list_ph08_best_chunk.wav
# Best chunk saved to train_pfstar/207f08sp_list_ph17_best_chunk.wav
# Best chunk saved to train_pfstar/024m10nl_digits9_best_chunk.wav
# Best chunk saved to train_pfstar/175m10sp_list_ph20_best_chunk.wav
# Best chunk saved to train_pfstar/120m06nl_digits6_best_chunk.wav
# Best chunk saved to train_pfstar/120f06nl_adapt_list_2_best_chunk.wav

# %%
import webrtcvad
import wave
import contextlib
import os

def read_wave(path):
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        sample_rate = wf.getframerate()
        frames = wf.readframes(wf.getnframes())
        return frames, sample_rate

def write_wave(path, audio, sample_rate):
    with wave.open(path, 'wb') as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(sample_rate)
        wf.writeframes(audio)

def remove_silence(audio_path, output_folder, chunk_duration_ms=2000, aggressiveness=3):
    vad = webrtcvad.Vad(aggressiveness)
    frames, sample_rate = read_wave(audio_path)

    frame_duration = 20  # Duration of each frame in ms
    frame_size = int(sample_rate * frame_duration / 1000) * 2

    speech_audio = b""

    # Process each frame and keep only the ones with detected speech
    for i in range(0, len(frames), frame_size):
        frame = frames[i:i + frame_size]
        if len(frame) < frame_size:
            break
        if vad.is_speech(frame, sample_rate):
            speech_audio += frame

    # Truncate to 3 seconds if necessary
    max_duration_bytes = (sample_rate * chunk_duration_ms // 1000) * 2
    best_chunk = speech_audio[:max_duration_bytes]

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Create the output file path in the `no_silence` folder
    output_path = os.path.join(output_folder, os.path.basename(audio_path).replace(".wav", ".wav"))
    write_wave(output_path, best_chunk, sample_rate)
    print(f"Processed audio saved to {output_path}")

def process_folder(folder_path, chunk_duration_ms=2000, aggressiveness=3):
    output_folder = os.path.join(folder_path, "chunk_2s")
    for filename in os.listdir(folder_path):
        if filename.endswith(".wav"):
            audio_path = os.path.join(folder_path, filename)
            remove_silence(audio_path, output_folder, chunk_duration_ms, aggressiveness)

# Folder path containing the audio files
folder_path = "test_pfstar"
process_folder(folder_path, chunk_duration_ms=2000)
# Out:
# Processed audio saved to test_pfstar/chunk_2s/005m08bh_w_list5b.wav
# Processed audio saved to test_pfstar/chunk_2s/021f11nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/004m10bh_list_ph04.wav
# Processed audio saved to test_pfstar/chunk_2s/082f06nl_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/029m10nl_list_4.wav
# Processed audio saved to test_pfstar/chunk_2s/042f06nl_list_ph02.wav
# Processed audio saved to test_pfstar/chunk_2s/196f08sp_list_1.wav
# Processed audio saved to test_pfstar/chunk_2s/020m12bh_w_list5b.wav
# Processed audio saved to test_pfstar/chunk_2s/025m10nl_w_list5.wav
# Processed audio saved to test_pfstar/chunk_2s/042f07nl_list_ph02.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/190f08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/177f09sp_sentences2or7b.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_list_5.wav
# Processed audio saved to test_pfstar/chunk_2s/005m10bh_list_ph05.wav
# Processed audio saved to test_pfstar/chunk_2s/162f09sp_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_digits4.wav
# Processed audio saved to test_pfstar/chunk_2s/003m13bh_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/162f09sp_list_ph12.wav
# Processed audio saved to test_pfstar/chunk_2s/163f10sp_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/038m11nl_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/163f10sp_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/030m10nl_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/004m10bh_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/004m08bh_list_ph14.wav
# Processed audio saved to test_pfstar/chunk_2s/021f11nl_list_ph21.wav
# Processed audio saved to test_pfstar/chunk_2s/044m07nl_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/005f06bh_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/017f10nl_list_ph22.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/168f09sp_list_ph18.wav
# Processed audio saved to test_pfstar/chunk_2s/043m06bh_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/208f08sp_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/194f08sp_w_list4a.wav
# Processed audio saved to test_pfstar/chunk_2s/032m11nl_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/014f11nl_w_list4.wav
# Processed audio saved to test_pfstar/chunk_2s/041f08nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/178m09sp_list_ph18.wav
# Processed audio saved to test_pfstar/chunk_2s/020m10nl_w_list5.wav
# Processed audio saved to test_pfstar/chunk_2s/004m08bh_list_ph04.wav
# Processed audio saved to test_pfstar/chunk_2s/194f08sp_list_ph04.wav
# Processed audio saved to test_pfstar/chunk_2s/045f07nl_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/006m10nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/012f11nl_list_ph22.wav
# Processed audio saved to test_pfstar/chunk_2s/045m06nl_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/007m10nl_list_ph02.wav
# Processed audio saved to test_pfstar/chunk_2s/035m10nl_w_list5.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/201m08sp_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_w_list4a.wav
# Processed audio saved to test_pfstar/chunk_2s/006m10nl_w_list1.wav
# Processed audio saved to test_pfstar/chunk_2s/032m11nl_list_ph02.wav
# Processed audio saved to test_pfstar/chunk_2s/039f11nl_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/043m06bh_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/020m10nl_list_ph20.wav
# Processed audio saved to test_pfstar/chunk_2s/021f11nl_w_list1.wav
# Processed audio saved to test_pfstar/chunk_2s/027m10nl_list_ph27.wav
# Processed audio saved to test_pfstar/chunk_2s/043m07nl_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/201m08sp_digits1.wav
# Processed audio saved to test_pfstar/chunk_2s/036f10nl_list_1.wav
# Processed audio saved to test_pfstar/chunk_2s/042f06nl_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/005f06bh_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_list_ph20.wav
# Processed audio saved to test_pfstar/chunk_2s/194f08sp_list_ph34.wav
# Processed audio saved to test_pfstar/chunk_2s/035m10nl_list_ph05.wav
# Processed audio saved to test_pfstar/chunk_2s/004m04bh_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/004m08bh_w_list4b.wav
# Processed audio saved to test_pfstar/chunk_2s/028m10nl_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/045m06nl_list_ph15.wav
# Processed audio saved to test_pfstar/chunk_2s/042m10nl_list_ph12.wav
# Processed audio saved to test_pfstar/chunk_2s/045m06nl_w_list5b.wav
# Processed audio saved to test_pfstar/chunk_2s/031f10nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/020m10nl_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_list_4.wav
# Processed audio saved to test_pfstar/chunk_2s/040f09nl_list_ph05.wav
# Processed audio saved to test_pfstar/chunk_2s/004m10bh_sentences4or9b.wav
# Processed audio saved to test_pfstar/chunk_2s/201m08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/035m10nl_list_5.wav
# Processed audio saved to test_pfstar/chunk_2s/013f11nl_list_ph13.wav
# Processed audio saved to test_pfstar/chunk_2s/022m11bh_list_ph27.wav
# Processed audio saved to test_pfstar/chunk_2s/004m08bh_w_list4a.wav
# Processed audio saved to test_pfstar/chunk_2s/196f08sp_list_ph36.wav
# Processed audio saved to test_pfstar/chunk_2s/004m10bh_w_list4.wav
# Processed audio saved to test_pfstar/chunk_2s/022m11bh_list_ph22.wav
# Processed audio saved to test_pfstar/chunk_2s/015f10nl_list_ph15.wav
# Processed audio saved to test_pfstar/chunk_2s/031f10nl_list_ph31.wav
# Processed audio saved to test_pfstar/chunk_2s/004m13bh_sentences4or9b.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_digits10.wav
# Processed audio saved to test_pfstar/chunk_2s/039f11nl_list_ph39.wav
# Processed audio saved to test_pfstar/chunk_2s/041m06nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/027m10nl_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/017f10nl_digits7.wav
# Processed audio saved to test_pfstar/chunk_2s/004m04bh_digits4.wav
# Processed audio saved to test_pfstar/chunk_2s/005f06bh_w_list5b.wav
# Processed audio saved to test_pfstar/chunk_2s/020m12bh_list_5.wav
# Processed audio saved to test_pfstar/chunk_2s/035m10nl_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/189f08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/028m10nl_list_ph28.wav
# Processed audio saved to test_pfstar/chunk_2s/005m08bh_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_list_ph39.wav
# Processed audio saved to test_pfstar/chunk_2s/083f07nl_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/005m08bh_list_ph05.wav
# Processed audio saved to test_pfstar/chunk_2s/176m10sp_list_ph26.wav
# Processed audio saved to test_pfstar/chunk_2s/034m11nl_list_ph39.wav
# Processed audio saved to test_pfstar/chunk_2s/029m10nl_list_ph29.wav
# Processed audio saved to test_pfstar/chunk_2s/030m10nl_w_list5.wav
# Processed audio saved to test_pfstar/chunk_2s/021f11nl_list_1.wav
# Processed audio saved to test_pfstar/chunk_2s/194f08sp_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/028m10nl_list_ph33.wav
# Processed audio saved to test_pfstar/chunk_2s/042f07nl_list_ph12.wav
# Processed audio saved to test_pfstar/chunk_2s/196f08sp_w_list1a.wav
# Processed audio saved to test_pfstar/chunk_2s/005m08bh_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/041f08nl_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/004m10bh_list_ph14.wav
# Processed audio saved to test_pfstar/chunk_2s/210f08sp_w_list5b.wav
# Processed audio saved to test_pfstar/chunk_2s/043m07nl_digits8.wav
# Processed audio saved to test_pfstar/chunk_2s/025m10nl_digits5.wav
# Processed audio saved to test_pfstar/chunk_2s/031f10nl_list_1.wav
# Processed audio saved to test_pfstar/chunk_2s/014f11nl_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/004m08bh_digits9.wav
# Processed audio saved to test_pfstar/chunk_2s/199m08sp_list_ph04.wav
# Processed audio saved to test_pfstar/chunk_2s/033m10nl_list_3.wav
# Processed audio saved to test_pfstar/chunk_2s/163f10sp_list_3.wav
# Processed audio saved to test_pfstar/chunk_2s/005m10bh_w_list5a.wav
# Processed audio saved to test_pfstar/chunk_2s/041f07nl_digits6.wav
# Processed audio saved to test_pfstar/chunk_2s/005m08bh_list_ph15.wav
# Processed audio saved to test_pfstar/chunk_2s/017f10nl_list_ph27.wav
# Processed audio saved to test_pfstar/chunk_2s/194f08sp_list_ph39.wav
