# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 0
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# 2024-12-08 14:19:16.869902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-08 14:19:16.923191: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-08 14:19:16.939935: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-08 14:19:17.044692: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-08 14:19:18.317003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:43<00:00,  5.24it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 0
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:22<00:00,  5.71it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 2
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# 2024-12-07 16:56:17.537322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 16:56:17.559443: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 16:56:17.563780: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 16:56:17.577138: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-07 16:56:18.830308: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:46<00:00,  5.14it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 2
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:21<00:00,  6.09it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 3
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:19<00:00,  6.13it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 3
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:20<00:00,  6.20it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 4
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:33<00:00,  5.59it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 4
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:21<00:00,  6.01it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 5
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:47<00:00,  5.12it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 5
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:32<00:00,  3.97it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 6
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:44<00:00,  5.19it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 6
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:23<00:00,  5.42it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 8
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:34<00:00,  5.54it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 8
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:21<00:00,  6.01it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 9
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:17<00:00,  6.23it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 9
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:20<00:00,  6.15it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 10
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:48<00:00,  5.07it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 10
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:23<00:00,  5.59it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 11
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:03<00:00,  6.93it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 11
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:16<00:00,  7.75it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 12
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [01:58<00:00,  7.24it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 12
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:19<00:00,  6.68it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 13
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:00<00:00,  7.13it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 13
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:17<00:00,  7.17it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 15
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:02<00:00,  7.00it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 15
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:19<00:00,  6.62it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 16
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:03<00:00,  6.93it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 16
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:19<00:00,  6.52it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 17
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:09<00:00,  6.60it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 17
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:20<00:00,  6.40it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 18
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:19<00:00,  6.14it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 18
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:21<00:00,  6.03it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 19
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:11<00:00,  6.53it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 19
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:21<00:00,  6.03it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 20
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:13<00:00,  6.43it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 20
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:19<00:00,  6.46it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 21
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:06<00:00,  6.79it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 21
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:18<00:00,  6.98it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 23
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:03<00:00,  6.93it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 23
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:18<00:00,  6.97it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 24
device = torch.device("cpu")
model.to(device)

file_path = 'path_train.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/train_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 856/856 [02:11<00:00,  6.50it/s]

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import soundfile as sf
import torch
from tqdm import tqdm
import numpy as np

# Load the processor and model for Wav2Vec2
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-960h-lv60-self")
model.config.output_hidden_states = True

target_layer = 24
device = torch.device("cpu")
model.to(device)

file_path = 'path_test.txt'
with open(file_path, 'r') as file:
    audio_files = [line.strip() for line in file]

speaker_ids = []
layer_features = []

for audio_file in tqdm(audio_files):
    speaker_id = audio_file.split('/')[-1].split('-')[0]  # Adjust based on your file path format
    speaker_ids.append(speaker_id)
    
    audio_input, sample_rate = sf.read(audio_file)
    
    input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)
    
    with torch.no_grad():
        outputs = model(input_values)
    
    all_hidden_states = outputs.hidden_states
    layer_feature = all_hidden_states[target_layer].squeeze(0).cpu().numpy()
    
    pooled_feature = np.mean(layer_feature, axis=0)
    
    layer_features.append(pooled_feature)

layer_features = np.array(layer_features)
speaker_ids = np.array(speaker_ids)

np.savez(f'./layer_features_lv60_self/test_{target_layer}.npz', features=layer_features, speaker_ids=speaker_ids)
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 129/129 [00:19<00:00,  6.55it/s]
